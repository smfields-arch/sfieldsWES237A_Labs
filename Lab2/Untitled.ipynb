# %% [markdown]
# # Use the gpio.ipynb from lab as a starting point. Add a C++ function to reset all the GPIO pins on the chosen PMOD. I will use PMODB for Assignment1

# %%
# Interacting with GPIO from MicroBlaze (PMODB)
from pynq.overlays.base import BaseOverlay
import time
from datetime import datetime

base = BaseOverlay("base.bit")
